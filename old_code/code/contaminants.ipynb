# %%
import numpy as np
import pandas as pd

# %%
import contaminants as conts

# %%
df = conts.load_contaminants()
df
# Out:
#     code                            desc  units
# 0      1                             SO2  µg/m³
# 6      6                              CO  mg/m³
# 1      7                              NO  µg/m³
# 2      8                             NO2  µg/m³
# 3      9                           PM2.5  µg/m³
# 7     10                            PM10  µg/m³
# 4     12                             NOx  µg/m³
# 5     14                              O3  µg/m³
# 8     22                    Black Carbon  µg/m³
# 12   996   Flow 2 (Mesura interna equip)    NaN
# 11   997   Flow 1 (Mesura interna equip)    NaN
# 10   998  Flow C (Mesura interna equip)
# 9    999           Biomassa Black Carbon      %

# %%
df[df.code < 15]
# Out:
#    code   desc  units
# 0     1    SO2  µg/m³
# 6     6     CO  mg/m³
# 1     7     NO  µg/m³
# 2     8    NO2  µg/m³
# 3     9  PM2.5  µg/m³
# 7    10   PM10  µg/m³
# 4    12    NOx  µg/m³
# 5    14     O3  µg/m³

# %% [markdown]
# ## Stations Contaminants 2022

# %% [markdown]
# ![imagem.png](attachment:imagem.png)

# %%
cont_list = [8, 14, 7, 12, 10, 1, 6]

# %%
# pm2.5 não é medido? Nos dados afinal existe uma estação que mede.
